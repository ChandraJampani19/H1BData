# %%
from google.cloud import bigquery
import pandas as pd


client = bigquery.Client(project='datenglea')

# Define the dataset and table name
dataset_id = 'H1BData'
table_id = 'H1practisetable'  # Replace with your desired table name

# Define the schema for the table
schema = [
    bigquery.SchemaField('Record', 'INT64'),  # Rename 'Unnamed: 0' to 'id'
    bigquery.SchemaField('CASE_STATUS', 'STRING'),
    bigquery.SchemaField('EMPLOYER_NAME', 'STRING'),
    bigquery.SchemaField('SOC_NAME', 'STRING'),
    bigquery.SchemaField('JOB_TITLE', 'STRING'),
    bigquery.SchemaField('FULL_TIME_POSITION', 'STRING'),
    bigquery.SchemaField('PREVAILING_WAGE', 'FLOAT64'),  # Assuming numeric values
    bigquery.SchemaField('YEAR', 'INT64'),
    bigquery.SchemaField('WORKSITE', 'STRING'),
    bigquery.SchemaField('lon', 'FLOAT64'),
    bigquery.SchemaField('lat', 'FLOAT64'),
]


# Define the table reference
table_ref = client.dataset(dataset_id).table(table_id)

# Create the table
table = bigquery.Table(table_ref, schema=schema)
table = client.create_table(table)

print(f'Table {table_id} created in dataset {dataset_id}.')
# Out:
# ---------------------------------------------------------------------------
# Conflict                                  Traceback (most recent call last)
# <ipython-input-3-13b476523dac> in <cell line: 32>()
#      30 # Create the table
#      31 table = bigquery.Table(table_ref, schema=schema)
# ---> 32 table = client.create_table(table)
#      33
#      34 print(f'Table {table_id} created in dataset {dataset_id}.')
#
# /usr/local/lib/python3.10/dist-packages/google/cloud/bigquery/client.py in create_table(self, table, exists_ok, retry, timeout)
#     797         try:
#     798             span_attributes = {"path": path, "dataset_id": dataset_id}
# --> 799             api_response = self._call_api(
#     800                 retry,
#     801                 span_name="BigQuery.createTable",
#
# /usr/local/lib/python3.10/dist-packages/google/cloud/bigquery/client.py in _call_api(self, retry, span_name, span_attributes, job_ref, headers, **kwargs)
# ...

# %%
from google.cloud import bigquery
import pandas as pd

# Path to your CSV file in GCS
csv_file_path = 'gs://cloudstoragedat/Raw Data File/h1b_kaggle_data.csv'

# Read the CSV file into a DataFrame
df = pd.read_csv(csv_file_path)

# Display the DataFrame to check how it looks
print(df.head())
# Out:
#    Unnamed: 0          CASE_STATUS  \
# 0           1  CERTIFIED-WITHDRAWN
# 1           2  CERTIFIED-WITHDRAWN
# 2           3  CERTIFIED-WITHDRAWN
# 3           4  CERTIFIED-WITHDRAWN
# 4           5            WITHDRAWN
#
#                                        EMPLOYER_NAME  \
# 0                             UNIVERSITY OF MICHIGAN
# 1                             GOODMAN NETWORKS, INC.
# 2                          PORTS AMERICA GROUP, INC.
# 3  GATES CORPORATION, A WHOLLY-OWNED SUBSIDIARY O...
# 4                          PEABODY INVESTMENTS CORP.
#
#                         SOC_NAME                     JOB_TITLE  \
# 0  BIOCHEMISTS AND BIOPHYSICISTS  POSTDOCTORAL RESEARCH FELLOW
# 1               CHIEF EXECUTIVES       CHIEF OPERATING OFFICER
# 2               CHIEF EXECUTIVES         CHIEF PROCESS OFFICER
# 3               CHIEF EXECUTIVES   REGIONAL PRESIDEN, AMERICAS
# 4               CHIEF EXECUTIVES  PRESIDENT MONGOLIA AND INDIA
#
# ...

# %%
df = df.rename(columns={'Unnamed: 0': 'record'})

# %%
df.head()
# Out:
#    record          CASE_STATUS  \
# 0       1  CERTIFIED-WITHDRAWN
# 1       2  CERTIFIED-WITHDRAWN
# 2       3  CERTIFIED-WITHDRAWN
# 3       4  CERTIFIED-WITHDRAWN
# 4       5            WITHDRAWN
#
#                                        EMPLOYER_NAME  \
# 0                             UNIVERSITY OF MICHIGAN
# 1                             GOODMAN NETWORKS, INC.
# 2                          PORTS AMERICA GROUP, INC.
# 3  GATES CORPORATION, A WHOLLY-OWNED SUBSIDIARY O...
# 4                          PEABODY INVESTMENTS CORP.
#
#                         SOC_NAME                     JOB_TITLE  \
# 0  BIOCHEMISTS AND BIOPHYSICISTS  POSTDOCTORAL RESEARCH FELLOW
# 1               CHIEF EXECUTIVES       CHIEF OPERATING OFFICER
# 2               CHIEF EXECUTIVES         CHIEF PROCESS OFFICER
# 3               CHIEF EXECUTIVES   REGIONAL PRESIDEN, AMERICAS
# 4               CHIEF EXECUTIVES  PRESIDENT MONGOLIA AND INDIA
#
# ...

# %%
from google.cloud import bigquery

# Initialize BigQuery client
client = bigquery.Client(project='datenglea')

# Define the table reference
dataset_id = 'H1BData'
table_id = 'H1practisetable'
table_ref = client.dataset(dataset_id).table(table_id)

from google.cloud import bigquery

# Initialize BigQuery client
client = bigquery.Client(project='datenglea')

# Define the table reference
dataset_id = 'H1BData'
table_id = 'H1practisetable'
table_ref = client.dataset(dataset_id).table(table_id)

# Run a query to count the number of rows in the table
query = f"TRUNCATE TABLE  `{dataset_id}.{table_id}`"
query_job = client.query(query)

# %%
from google.cloud import bigquery
import pandas as pd

# Initialize BigQuery client
client = bigquery.Client(project='datenglea')

# Define the dataset and table name
dataset_id = 'H1BData'
table_id = 'H1practisetable'

# Define the table reference
table_ref = client.dataset(dataset_id).table(table_id)

# Upload the DataFrame to BigQuery
job = client.load_table_from_dataframe(df, table_ref)

# Wait for the job to complete
job.result()

print(f'Data successfully written to {dataset_id}.{table_id}.')
# Out:
# Data successfully written to H1BData.H1practisetable.

# %%
from google.cloud import bigquery

# Initialize BigQuery client
client = bigquery.Client(project='datenglea')

# Define the table reference
dataset_id = 'H1BData'
table_id = 'H1practisetable'
table_ref = client.dataset(dataset_id).table(table_id)

# Run a query to count the number of rows in the table
query = f"SELECT COUNT(*) as record_count FROM `{dataset_id}.{table_id}`"
query_job = client.query(query)

display = f"SELECT *  FROM `{dataset_id}.{table_id}`LIMIT 10"
d_query_job = client.query(display)

for row in d_query_job.result():
    print(row)
# Get the results
results = query_job.result()

# Print the count
for row in results:
    print(f"Total records: {row.record_count}")
# Out:
# Row((1, 'CERTIFIED-WITHDRAWN', 'UNIVERSITY OF MICHIGAN', 'BIOCHEMISTS AND BIOPHYSICISTS', 'POSTDOCTORAL RESEARCH FELLOW', 'N', 36067.0, 2016, 'ANN ARBOR, MICHIGAN', -83.7430378, 42.2808256), {'Record': 0, 'CASE_STATUS': 1, 'EMPLOYER_NAME': 2, 'SOC_NAME': 3, 'JOB_TITLE': 4, 'FULL_TIME_POSITION': 5, 'PREVAILING_WAGE': 6, 'YEAR': 7, 'WORKSITE': 8, 'lon': 9, 'lat': 10})
# Row((4, 'CERTIFIED-WITHDRAWN', 'GATES CORPORATION, A WHOLLY-OWNED SUBSIDIARY OF TOMKINS PLC', 'CHIEF EXECUTIVES', 'REGIONAL PRESIDEN, AMERICAS', 'Y', 220314.0, 2016, 'DENVER, COLORADO', -104.990251, 39.7392358), {'Record': 0, 'CASE_STATUS': 1, 'EMPLOYER_NAME': 2, 'SOC_NAME': 3, 'JOB_TITLE': 4, 'FULL_TIME_POSITION': 5, 'PREVAILING_WAGE': 6, 'YEAR': 7, 'WORKSITE': 8, 'lon': 9, 'lat': 10})
# ...
